# %% [markdown]
# # Data Preparation Script for the SpaceNet 5 Challenge

# %% [markdown]
# ## 1. Download data
#
# After setting up an AWS account, accessing SpaceNet data is free.  Let's download data for both SpaceNet 3 and SpaceNet 5.
#
#
# -----------------------
#
# ### A. SN3
#
# See https://spacenet.ai/spacenet-roads-dataset/ for further information
#
# Explore AOI_2_Vegas
#
#     aws s3 ls s3://spacenet-dataset/spacenet/SN3_roads/train/AOI_2_Vegas/
#        PRE MS/
#        PRE PAN/
#        PRE PS-MS/
#        PRE PS-RGB/
#        PRE geojson_roads/
#        PRE geojson_roads_speed/
#        PRE metadata/
#
#     aws s3 ls --summarize --human-readable --recursive s3://spacenet-dataset/spacenet/SN3_roads/tarballs/
#        Total Objects: 8
#        Total Size: 58.8 GiB
#
# download data
#
#     aws s3 cp --recursive s3://spacenet-dataset/spacenet/SN3_roads/tarballs/ /path/to/data/SN3_roads
#
# -----------------------
#
# ### B. SN5
#
# see https://spacenet.ai/sn5-challenge/ for further information
#
#     aws s3 ls s3://spacenet-dataset/spacenet/SN5_roads/
#     aws s3 ls --summarize --human-readable --recursive s3://spacenet-dataset/spacenet/SN5_roads/tarballs/
#
# download data
#
#     aws s3 cp --recursive s3://spacenet-dataset/spacenet/SN5_roads/tarballs/ /path/to/data/SN5_roads
#
#
# -----------------------
#
# ### C. untar SN3 and SN5 with tar -xvf
#
# Files have names like...
#
#     /path/to/data/SN3_roads/
#         PS-RGB/SN3_roads_train_AOI_2_Vegas_PS-RGB_img272.tif
#         geojson_roads_speed/SN3_roads_train_AOI_2_Vegas_geojson_roads_img272_speed.geojson
#
#     /path/to/data/SN5_roads/
#         PS-RGB/SN5_roads_train_AOI_7_Moscow_PS-RGB_chip390.tif
#         geojson_roads_speed/SN5_roads_train_AOI_7_Moscow_geojson_roads_speed_chip390.geojson

# %% [markdown]
# -----------------------
# ## 2. Install CRESI

# %% [markdown]
# To run [CRESI](https://github.com/CosmiQ/cresi)  you will need docker (ideally the nvidi-docker version) installed on a GPU-enabled machine.  All CRESI commands should be run within this docker container.
#
#
# % scp -r /raid/cosmiq/cresi_v2/ gpu08:/raid/local/src
#
#
# 1. Download:
#
#         cd /path/to/cresi/
#         git clone https://github.com/avanetten/cresi.git
#
#
# 2. Build docker image:
#
#         cd /path/to/cresi/docker
#         % cd /raid/local/src/cresi_v2/docker
#         nvidia-docker build --no-cache -t cresi_v2_image .
#         nvidia-docker build -t cresi_v2_image .
#
#
# 3. Create docker container:
#
#         NV_GPU=0 nvidia-docker run -it -v /path/to/cresi:/path/to/cresi -v /path/to/data:/path/to/data --rm -ti --ipc=host --name cresi_v2_gpu0 cresi_v2_image
#         % NV_GPU=0 nvidia-docker run -it -v /raid:/raid -v /nfs:/nfs --rm -ti --ipc=host --name cresi_v2_gpu0 cresi_v2_image
#         % NV_GPU=1 nvidia-docker run -it -v /raid:/raid -v /nfs:/nfs --rm -ti --ipc=host --name cresi_v2_gpu1 cresi_v2_image
#
#
# 4. Attache docker container:
#
#         docker attach cresi_v2_gpu0

# %% [markdown]
# -----------------------
# ## 3. Imagery
#
# SpaceNet 3 and SpaceNet 5 data formats are slightly different, due to extra post-processing performed on the SpaceNet 5 imagery.  The RGB 3-band pan-sharpened imagery (PS-RGB) for SpaceNet 3 was distrubuted in the native 16-bit data format.  In SpaceNet 5 the RGB 3-band pan-sharpened imagery utilized the Maxar DRA (Dynamic Range Adjusted) product which seeks to equalize color scales, and yields an 8-bit image.  The pan-sharpened 8-band multispecral images (PS-MS) are prepared the same for both challenges, so we will utilize this data for training and testing.
#
# While we lose a significant amount of information by utilizing only a subset of the multispectral bands, for ease of exploration we extract the 8-bit RGB imagery from the 16-bit multispectral imagery, where RGB corresponds to bands 5,3,2, respectively.  This is accomplished via the `create_8bit_images.py` script.  In this example, we rescale the image to the 2nd and 98th percentile of pixel values when converting to 8-bit. The script below should be run for all 6 training areas of interest (AOIs): AOI_2_Vegas, AOI_3_Paris, AOI_4_Shanghai, AOI_5_Khartoum, AOI_7_Moscow, AOI_8_Mumbai.
#
#     python /path/to/cresi/cresi/data_prep/create_8bit_images.py \
#         --indir=/path/to/data/SN3_roads/AOI_4_Shanghai/PS-MS \
#         --outdir=/path/to/data/cresi_data/8bit/PS-RGB \
#         --rescale_type=perc \
#         --percentiles=2,98 \
#         --band_order=5,3,2
#
#     python /path/to/cresi/cresi/data_prep/create_8bit_images.py \
#         --indir=/path/to/data/SN5_roads/AOI_7_Moscow/PS-MS \
#         --outdir=/path/to/data/cresi_data/8bit/PS-RGB \
#         --rescale_type=perc \
#         --percentiles=2,98 \
#         --band_order=5,3,2
#
#
# % below here is for testing
# % scp -r /raid/cosmiq/cresi_v2/ gpu08:/raid/local/src
#
#     python /raid/local/src/cresi_v2/cresi/data_prep/create_8bit_images.py \
#         --indir=/raid/data/spacenet/SN3_roads/AOI_4_Shanghai/PS-MS \
#         --outdir=/raid/data/spacenet/cresi_data/8bit/PS-RGB \
#         --rescale_type=perc \
#         --percentiles=2,98 \
#         --band_order=5,3,2
#
#     python /raid/local/src/cresi_v2/cresi/data_prep/create_8bit_images.py \
#         --indir=/raid/data/spacenet/SN5_roads/AOI_7_Moscow/PS-MS \
#         --outdir=/raid/data/spacenet/cresi_data/8bit/PS-RGB \
#         --rescale_type=perc \
#         --percentiles=2,98 \
#         --band_order=5,3,2
#
#
# % inspect
# % scp -r gpu08:/raid/data/spacenet/cresi_data/8bit/PS-RGB/*Shanghai* /raid/cosmiq/spacenet/competitions/ex/8bit/PS-RGB
# % scp -r gpu08:/raid/data/spacenet/cresi_data/8bit/PS-RGB/*Shanghai* //raid/cosmiq/spacenet/competitions/ex/8bit/PS-RGB

# %% [markdown]
# ## 2. Explore images and geojsons

# %%
# First let's inspect an image

import os
import cv2
import skimage.io
import numpy as np
import osmnx as ox
import geopandas as gpd
import matplotlib.pyplot as plt

data_root_dir = '/path/to/data/cresi_data/8bit/PS-RGB'

data_root_dir = '/raid/cosmiq/spacenet/competitions/ex/8bit/PS-RGB'

im_path_sample = os.path.join(
    data_root_dir, 'SN5_roads_train_AOI_8_Mumbai_PS-MS_chip203.tif')

# view image
fig_width, fig_height = 10, 10
im = cv2.imread(im_path_sample, 1)
print ("im.shape:", im.shape)
fig, ax = plt.subplots(figsize=(fig_width, fig_height))
_ = ax.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
ax.axis('off')
# Out:
# im.shape: (1300, 1300, 3)
# (-0.5, 1299.5, 1299.5, -0.5)

# %%
# visualize geojsons

data_root_dir = '/path/to/data/SN5_roads/'
data_root_dir = '/raid/cosmiq/spacenet/competitions/SN5_roads/train/AOI_8_Mumbai'

geojson_path_sample = os.path.join(
    data_root_dir, 'geojson_roads_speed/SN5_roads_train_AOI_8_Mumbai_geojson_roads_speed_chip203.geojson')

# define road buffer width 
bufferDistanceMeters = 2

# get gdf_buffer
inGDF = gpd.read_file(geojson_path_sample)
print ("inGDF.columns:", inGDF.columns)
print ("\nsample gdf row:", inGDF.iloc[0])

# # project via osmnx
projGDF = ox.project_gdf(inGDF)
# get bounds
bounds = projGDF.geometry.total_bounds
print("\nprojGDF.geometry.total_bounds:", bounds)
# get extent
print("\nx_extent =", bounds[2] - bounds[0])
print("y_extent =", bounds[3] - bounds[1])

# explore buffer
#   https://shapely.readthedocs.io/en/latest/manual.html#object.buffer
gdf_utm_buffer = projGDF.copy()
# perform Buffer to produce polygons from Line Segments
gdf_utm_buffer['geometry'] = gdf_utm_buffer.buffer(bufferDistanceMeters, 1)
gdf_utm_dissolve = gdf_utm_buffer.dissolve(by='truncated')
gdf_utm_dissolve.crs = gdf_utm_buffer.crs
gdf_buffer = gdf_utm_dissolve.to_crs(inGDF.crs)
# display
gdf_utm_dissolve['geometry'][0]
# Out:
# inGDF.columns: Index(['OBJECTID', 'bridge', 'highway', 'osm_id', 'surface', 'lanes',
#        'inferred_speed_mph', 'inferred_speed_mps', 'origarea', 'origlen',
#        'partialDec', 'truncated', 'geometry'],
#       dtype='object')
#
# sample gdf row: OBJECTID                                                           5940
# bridge                                                             None
# highway                                                        tertiary
# osm_id                                                      6.83692e+08
# surface                                                           paved
# lanes                                                                 1
# inferred_speed_mph                                                   30
# inferred_speed_mps                                              13.4112
# origarea                                                              0
# origlen                                                               0
# ...

# %% [markdown]
# ## 4. Create Masks

# %% [markdown]
# The `geojson_roads_speed` folder within each area of interest (AOI) directory contains road centerline labels along with estimtates of safe travel speeds for each roadway (see https://github.com/CosmiQ/apls/blob/master/apls/road_speed.py for further details).  We'll use these centerline labels and speed estimates to create training masks.  We explore two options, continuous masks and multi-channel masks.

# %% [markdown]
# ### 4.1. Continous Masks

# %% [markdown]
# One option for training a segmentation model is to create training masks where the value of the mask is proportional to the speed of the roadway. This can be accomplished by running the `speed_masks.py` script.  In the following example, we assume data is in: `/raid/data/spacenet/`
#
#
#     # SN3
#     python /path/to/cresi/cresi/data_prep/speed_masks.py \
#         --geojson_dir=/path/to/data/SN3_roads/AOI_2_Vegas/geojson_roads_speed \
#         --image_dir=/path/to/data/SN3_roads/AOI_2_Vegas/PS-MS \
#         --output_conversion_csv=/path/to/data/cresi_data/cresi_train/SN3_roads_train_speed_conversion_continuous.csv \
#         --output_mask_dir=/path/to/data/cresi_data/cresi_train/train_mask_continuous
#
#     # SN5
#     python /path/to/cresi/cresi/data_prep/speed_masks.py \
#         --geojson_dir=/path/to/data/SN5_roads/AOI_7_Moscow/geojson_roads_speed \
#         --image_dir=/path/to/data/SN5_roads/AOI_7_Moscow/PS-MS \
#         --output_conversion_csv=/path/to/data/cresi_data/cresi_train/SN5_roads_train_speed_conversion_continuous.csv \
#         --output_mask_dir=/path/to/data/cresi_data/cresi_train/train_mask_continuous
#
#
# %%%%
# scp -r /raid/cosmiq/cresi_v2/ gpu08:/raid/local/src
#
#
#     #python /path/to/cresi/cresi/data_prep/speed_masks.py \
#     # SN3
#     python /raid/local/src/cresi_v2/cresi/data_prep/speed_masks.py \
#         --geojson_dir=/raid/data/spacenet/SN3_roads/AOI_2_Vegas/geojson_roads_speed \
#         --image_dir=/raid/data/spacenet/SN3_roads/AOI_2_Vegas/PS-MS \
#         --output_conversion_csv=/raid/data/spacenet/cresi_data/cresi_train/SN3_roads_train_speed_conversion_continuous.csv \
#         --output_mask_dir=/raid/data/spacenet/cresi_data/cresi_train/train_mask_continuous
#
#     # SN5
#     python /raid/local/src/cresi_v2/cresi/data_prep/speed_masks.py \
#         --geojson_dir=/raid/data/spacenet/SN5_roads/AOI_7_Moscow/geojson_roads_speed \
#         --image_dir=/raid/data/spacenet/SN5_roads/AOI_7_Moscow/PS-MS \
#         --output_conversion_csv=/raid/data/spacenet/cresi_data/cresi_train/SN5_roads_train_speed_conversion_continuous.csv \
#         --output_mask_dir=/raid/data/spacenet/cresi_data/cresi_train/train_mask_continuous
#
# scp -r gpu08:/raid/data/spacenet/cresi_data/cresi_train/train_mask_continuous/*Moscow* /raid/cosmiq/spacenet/competitions/ex/train_mask_continuous

# %%
# Inspect files

im_dir = '/path/to/data/cresi_data/8bit/PS-RGB'
mask_dir = '/path/to/data/cresi_data/cresi_train/train_mask_continuous'

im_dir = '/raid/cosmiq/spacenet/competitions/ex/8bit/PS-RGB/'
mask_dir = '/raid/cosmiq/spacenet/competitions/ex/train_mask_continuous'

im_name = 'SN5_roads_train_AOI_7_Moscow_PS-MS_chip371.tif'
im_path = os.path.join(im_dir, im_name)
mask_contin_path = os.path.join(mask_dir, im_name)

fig, ((ax0, ax1, ax2)) = plt.subplots(1,3, figsize=(20,7))

# image
im = cv2.imread(im_path, 1)
ax0.imshow(cv2.imread(im_path, 1))
ax0.axis('off')
ax0.set_title(im_name)

# binary mask
ax1.imshow(255*np.clip(cv2.imread(mask_contin_path, 1), 0, 1))
ax1.axis('off')
ax1.set_title('Typical Binary Mask')

# continuous mask
z = ax2.imshow(cv2.imread(mask_contin_path, 1))
ax2.axis('off')
ax2.set_title('Continuous Mask')



# # fig, ((ax0, ax1), (ax2, ax3)) = plt.subplots(2,2, figsize=(20,20))

# # # image
# # im = cv2.imread(im_path, 1)
# # print("im.shape:", im.shape)
# # ax0.imshow(cv2.imread(im_path, 1))

# # # contin mask
# # ax1.imshow(cv2.imread(mask_contin_path, 1))

# # # binned mask
# # ax2.imshow(cv2.imread(mask_bin_path, 1))

# # # multiclass binned mask
# # mask_bin_mc = skimage.io.imread(mask_bin_mc_path)
# # # mask_bin_mc = cv2.imread(mask_bin_mc_path, 1)
# # print("mask_bin_mc.shape:", mask_bin_mc.shape)
# # print("mask_bin_mc[-1,:,:]).shape:", mask_bin_mc[-1,:,:].shape)
# # ax3.imshow(mask_bin_mc[-1,:,:])
# Out:
# Text(0.5, 1.0, 'Continuous Mask')

# %% [markdown]
# ### 4.2 Multi-channel masks

# %% [markdown]
# A second option for training a segmentation model is to create multi-channel training masks where each channel corresponds to a speed range.  In the script below we bin in 10 mph increments, for a total of 7 bins.  We also append the total binary mask (this aids in initial road extraction), for a total of 8 bins.
#
#
#     # SN5 - binned
#     python /path/to/cresi/cresi/data_prep/speed_masks.py \
#         --geojson_dir=/path/to/data/SN5_roads/AOI_8_Mumbai/geojson_roads_speed \
#         --image_dir=/path/to/data/SN5_roads/AOI_8_Mumbai/PS-MS \
#         --output_conversion_csv=/path/to/data/cresi_data/cresi_train/SN5_roads_train_speed_conversion_binned.csv \
#         --output_mask_dir=/path/to/data/cresi_data/cresi_train/train_mask_binned
#         --output_mask_multidim_dir=/path/to/data/cresi_data/cresi_train/train_mask_binned_mc
#
#
# %%%%%
#
#         # binned
#         python /raid/local/src/cresi_v2/cresi/data_prep/speed_masks.py \
#             --geojson_dir=/raid/data/spacenet/SN5_roads/AOI_8_Mumbai/geojson_roads_speed \
#             --image_dir=/raid/data/spacenet/SN5_roads/AOI_8_Mumbai/PS-MS \
#             --output_conversion_csv=/raid/data/spacenet/cresi_data/cresi_train/SN5_roads_train_speed_conversion_continuous.csv \
#             --output_mask_dir=/raid/data/spacenet/cresi_data/cresi_train/train_mask_binned \
#             --output_mask_multidim_dir=/raid/data/spacenet/cresi_data/cresi_train/train_mask_binned_mc
#
#           # Inspect files
#
#             scp -r gpu08:/raid/data/spacenet/cresi_data/cresi_train/train_mask_binned_mc/*Mumbai* /raid/cosmiq/spacenet/competitions/ex/train_mask_binned_mc

# %%
im_dir = '/path/to/data/cresi_data/8bit/PS-RGB'
mask_dir = '/path/to/data/cresi_data/cresi_train/train_mask_binned_mc'

im_dir = '/raid/cosmiq/spacenet/competitions/ex/8bit/PS-RGB/'
mask_dir = '/raid/cosmiq/spacenet/competitions/ex/train_mask_binned_mc'

im_name = 'SN5_roads_train_AOI_8_Mumbai_PS-MS_chip35.tif'
im_path = os.path.join(im_dir, im_name)
mask_mc_path = os.path.join(mask_dir, im_name)

fig, ((ax0, ax1, ax2)) = plt.subplots(1,3, figsize=(24,9))

# image
im = cv2.imread(im_path, 1)
ax0.imshow(cv2.imread(im_path, 1))
ax0.axis('off')
ax0.set_title(im_name)

mask_mc = skimage.io.imread(mask_mc_path)
print("multi-channel mask shape:", mask_mc.shape)

# binary mask
ax1.imshow(mask_mc[:,:,-1])
ax1.axis('off')
ax1.set_title('Typical Binary Mask')

# 8 channel mask
z = ax2.imshow(mask_mc[:,:,2:5])
ax2.axis('off')
ax2.set_title('Multi-channel Mask (colored by speed)')



# # fig, ((ax0, ax1), (ax2, ax3)) = plt.subplots(2,2, figsize=(20,20))

# # # image
# # im = cv2.imread(im_path, 1)
# # print("im.shape:", im.shape)
# # ax0.imshow(cv2.imread(im_path, 1))

# # # contin mask
# # ax1.imshow(cv2.imread(mask_contin_path, 1))

# # # binned mask
# # ax2.imshow(cv2.imread(mask_bin_path, 1))

# # # multiclass binned mask
# # mask_bin_mc = skimage.io.imread(mask_bin_mc_path)
# # # mask_bin_mc = cv2.imread(mask_bin_mc_path, 1)
# # print("mask_bin_mc.shape:", mask_bin_mc.shape)
# # print("mask_bin_mc[-1,:,:]).shape:", mask_bin_mc[-1,:,:].shape)
# # ax3.imshow(mask_bin_mc[-1,:,:])
# Out:
# multi-channel mask shape: (1300, 1300, 8)
# Text(0.5, 1.0, 'Multi-channel Mask (colored by speed)')
